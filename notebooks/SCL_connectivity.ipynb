# %% [markdown]
# ## Supratidal and Coastal Lowland connectivity model

# %%
import sys

import numpy as np
import xarray as xr
import geopandas as gpd

from odc.geo.gridspec import GridSpec
from odc.geo.geobox import GeoBox
from odc.geo.geom import BoundingBox
from odc.geo.types import xy_

import datacube
dc = datacube.Datacube()

from dea_tools.datahandling import load_reproject

sys.path.insert(1, "/home/jovyan/code/supratidal_forests/data")
from gridspec_96km_tiles import tiles

sys.path.insert(1, "/home/jovyan/code/supratidal_forests/functions")
from least_cost_path import xr_cost_distance, load_connectivity_mask_aquatic

# %% [markdown]
# ### setup gridspec

# %%
# Expanded Extents 96 km tiling grid
gs_c3_expanded = GridSpec(
    crs="EPSG:3577",
    resolution=30,
    tile_shape=(3200, 3200),
    origin=xy_(-4416000, -6912000),
)

# %%
# Visualising whole grid
# Set bounding box
c3_bbox = BoundingBox(
    left=-2400000, bottom=-5088000, right=2784000, top=-864000, crs="EPSG:3577"
)

# Convert grid to geopandas polygon dataset covering full C3 grid extent
grid_gdf = gpd.GeoDataFrame.from_features(
    gs_c3_expanded.geojson(bbox=c3_bbox),
    crs="EPSG:4326", # CRS different here just for visualisation
)
grid_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84ad1d2aea07b76ca840936197e4293a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84ad1d2aea07b76ca840936197e4293a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84ad1d2aea07b76ca840936197e4293a = L.map(
#                 &quot;map_84ad1d2aea07b76ca840936197e4293a&quot;,
#                 {
#                     center: [-26.22508639363491, 134.22722471638417],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_84ad1d2aea07b76ca840936197e4293a);
#
#
#
#
#
#             var tile_layer_d9ff7417e53c31da2443f8504ed15c6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9ff7417e53c31da2443f8504ed15c6c.addTo(map_84ad1d2aea07b76ca840936197e4293a);
#
#
#             map_84ad1d2aea07b76ca840936197e4293a.fitBounds(
#                 [[-46.65245728235133, 102.92835819887652], [-5.7977155049184965, 165.5260912338918]],
#                 {}
#             );
#
#
#         function geo_json_520170f9fc956587a56d35247d1cd888_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_520170f9fc956587a56d35247d1cd888_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_520170f9fc956587a56d35247d1cd888_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_520170f9fc956587a56d35247d1cd888_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_520170f9fc956587a56d35247d1cd888_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_520170f9fc956587a56d35247d1cd888.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_520170f9fc956587a56d35247d1cd888_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_520170f9fc956587a56d35247d1cd888 = L.geoJson(null, {
#                 onEachFeature: geo_json_520170f9fc956587a56d35247d1cd888_onEachFeature,
#
#                 style: geo_json_520170f9fc956587a56d35247d1cd888_styler,
#                 pointToLayer: geo_json_520170f9fc956587a56d35247d1cd888_pointToLayer,
#         });
#
#         function geo_json_520170f9fc956587a56d35247d1cd888_add (data) {
#             geo_json_520170f9fc956587a56d35247d1cd888
#                 .addData(data);
#         }
#             geo_json_520170f9fc956587a56d35247d1cd888_add({&quot;bbox&quot;: [102.92835819887652, -46.65245728235133, 165.5260912338918, -5.7977155049184965], &quot;features&quot;: [{&quot;bbox&quot;: [102.92835819887652, -44.262376011817075, 104.30224084230278, -43.19096473186957], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[103.18617279389052, -43.19096473186957], [102.92835819887652, -44.063520331211414], [104.05375596545665, -44.262376011817075], [104.30224084230278, -43.38698017009005], [103.18617279389052, -43.19096473186957]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;idx&quot;: &quot;21,19&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [104.05375596545665, -44.45374040137284, 105.4226204903847, -43.38698017

# %%
# User input, select tiles from list
print(tiles)
# Out:
# [(57, 60), (58, 60), (43, 59), (44, 59), (45, 59), (46, 59), (47, 59), (48, 59), (50, 59), (51, 59), (57, 59), (58, 59), (44, 58), (45, 58), (46, 58), (47, 58), (48, 58), (49, 58), (50, 58), (51, 58), (57, 58), (58, 58), (43, 57), (44, 57), (45, 57), (46, 57), (49, 57), (50, 57), (51, 57), (56, 57), (57, 57), (58, 57), (59, 57), (38, 56), (39, 56), (40, 56), (41, 56), (42, 56), (43, 56), (44, 56), (49, 56), (50, 56), (51, 56), (56, 56), (57, 56), (59, 56), (37, 55), (38, 55), (39, 55), (41, 55), (42, 55), (43, 55), (49, 55), (50, 55), (56, 55), (57, 55), (59, 55), (60, 55), (37, 54), (38, 54), (41, 54), (42, 54), (43, 54), (44, 54), (49, 54), (50, 54), (51, 54), (52, 54), (56, 54), (57, 54), (60, 54), (61, 54), (35, 53), (36, 53), (37, 53), (38, 53), (51, 53), (52, 53), (53, 53), (54, 53), (56, 53), (57, 53), (60, 53), (61, 53), (35, 52), (36, 52), (37, 52), (53, 52), (54, 52), (55, 52), (56, 52), (60, 52), (61, 52), (34, 51), (35, 51), (53, 51), (54, 51), (55, 51), (56, 51), (61, 51), (34, 50), (61, 50), (32, 49), (33, 49), (34, 49), (61, 49), (62, 49), (29, 48), (30, 48), (31, 48), (32, 48), (62, 48), (63, 48), (64, 48), (28, 47), (29, 47), (30, 47), (63, 47), (64, 47), (26, 46), (27, 46), (28, 46), (64, 46), (26, 45), (27, 45), (64, 45), (65, 45), (26, 44), (27, 44), (65, 44), (66, 44), (26, 43), (27, 43), (65, 43), (66, 43), (26, 42), (27, 42), (66, 42), (67, 42), (68, 42), (26, 41), (27, 41), (67, 41), (68, 41), (26, 40), (27, 40), (67, 40), (27, 39), (28, 39), (67, 39), (28, 38), (67, 38), (28, 37), (29, 37), (66, 37), (67, 37), (29, 36), (43, 36), (44, 36), (45, 36), (66, 36), (67, 36), (29, 35), (30, 35), (39, 35), (40, 35), (41, 35), (42, 35), (43, 35), (45, 35), (46, 35), (47, 35), (48, 35), (51, 35), (66, 35), (29, 34), (30, 34), (38, 34), (39, 34), (47, 34), (48, 34), (51, 34), (65, 34), (66, 34), (30, 33), (35, 33), (36, 33), (37, 33), (38, 33), (48, 33), (49, 33), (50, 33), (51, 33), (64, 33), (65, 33), (29, 32), (30, 32), (33, 32), (34, 32), (35, 32), (36, 32), (37, 32), (48, 32), (49, 32), (50, 32), (51, 32), (52, 32), (53, 32), (63, 32), (64, 32), (29, 31), (30, 31), (31, 31), (32, 31), (33, 31), (50, 31), (51, 31), (52, 31), (53, 31), (63, 31), (64, 31), (50, 30), (51, 30), (52, 30), (53, 30), (62, 30), (63, 30), (53, 29), (62, 29), (63, 29), (53, 28), (54, 28), (55, 28), (57, 28), (58, 28), (60, 28), (61, 28), (62, 28), (54, 27), (55, 27), (56, 27), (57, 27), (58, 27), (59, 27), (60, 27), (61, 27), (62, 27), (56, 26), (58, 26), (59, 26), (56, 25), (57, 25), (60, 25), (57, 24), (58, 24), (59, 24), (60, 24), (57, 23), (58, 23), (59, 23), (60, 23), (57, 22), (58, 22), (59, 22), (60, 22), (58, 21), (59, 21)]

# %%
# Extract GeoBox for specific tile 
bbox = tiles[209]
geobox = gs_c3_expanded[bbox]  
geobox.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_778538f66e9e2840d2a4297d2c5fa6ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_778538f66e9e2840d2a4297d2c5fa6ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_778538f66e9e2840d2a4297d2c5fa6ea = L.map(
#                 &quot;map_778538f66e9e2840d2a4297d2c5fa6ea&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd0ebda7853ae39b863939146260c05b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd0ebda7853ae39b863939146260c05b.addTo(map_778538f66e9e2840d2a4297d2c5fa6ea);
#
#
#
#         function geo_json_8bc908a92bd7ddb471abf7d815e2e0ee_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8bc908a92bd7ddb471abf7d815e2e0ee = L.geoJson(null, {
#                 onEachFeature: geo_json_8bc908a92bd7ddb471abf7d815e2e0ee_onEachFeature,
#
#         });
#
#         function geo_json_8bc908a92bd7ddb471abf7d815e2e0ee_add (data) {
#             geo_json_8bc908a92bd7ddb471abf7d815e2e0ee
#                 .addData(data);
#         }
#             geo_json_8bc908a92bd7ddb471abf7d815e2e0ee_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[150.72024987936936, -33.16150084272217], [151.7442057879841, -33.03259871026674], [151.9048167364147, -33.88233646556849], [150.87278105129633, -34.01248835098754], [150.72024987936936, -33.16150084272217]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [150.72024987936936, -33.16150084272217], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_8bc908a92bd7ddb471abf7d815e2e0ee.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8bc908a92bd7ddb471abf7d815e2e0ee.addTo(map_778538f66e9e2840d2a4297d2c5fa6ea);
#
#
#             map_778538f66e9e2840d2a4297d2c5fa6ea.fitBounds(
#                 [[-34.01248835098754, 150.72024987936936], [-33.03259871026674, 151.9048167364147]],
#                 {}
#             );
#
#
#         function geo_json_ee766dff4b15f17270e9acac85470ddf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ee766dff4b15f17270e9acac85470ddf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ee766dff4b15f17270e9acac85470ddf = L.geoJson(null, {
#                 onEachFeature: geo_json_ee766dff4b15f17270e9acac85470ddf_onEachFeature,
#
#                 style: geo_json_ee766dff4b15f17270e9acac85470ddf_styler,
#         });
#
#         function geo_json_ee766dff4b15f17270e9acac85470ddf_add (data) {
#             geo_json_ee766dff4b15f17270e9acac85470ddf
#                 .addData(data);
#         }
#             geo_json_ee766dff4b15f17270e9acac85470ddf_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[150.880406186119, -33.14180717180449], [150.9042742204335, -33.274665159480364], [150.92820223486038, -33.407551119872224], [150.95219045409297, -33.54046589918173], [150.97623910393983, -33.673410348754786], [151.00034841133152, -33.80638532516407], [151.0245186043275, -33.93939169029254], [151.03420378079653, -33.99260321927232]], [[151.04050273652496, -33.12194767967528], [151.06456714522463, -33.254776082150926], [151.0886920047816, -33.38763225499625], [151.1128775415381, -33.52051704286771], [151.13712398295903, -33.6534312955458], [151.16143155763876, -33.786375868017245], [151.18580049530814, -33.919351620558196], [151.19556530369022, -33.97255084571707]], [[151.20053906148496, -33.101922474323715], [151.22479961934434, -33.23472107435027], [151.2491210976903, -33.367547240992174], [151.27350372450704, -33.500401817351786], [151.29794772890887, -33.63328565163511], [151.32245334114697, -33.7661995972339], [151.34702079261655, -33.8991445128081], [151.3568651402407, -33.95233134398793]], [[151.3605146930056, -33.08173166444122], [151.38497117316476, -33.21450024564128], [151.40948904231658, -33.347296188301996], [151.43406853008042, -33.48012033396274], [151.45870986721303, -33.61297352924609], [151.48341328561548, -33.74585662593967], [151.5081790183403, -33.878770481078206], [151.51810281186465, -33.93194482848713]], [[151.52042916420976, -33.06137535941641], [151.54508133818086, -33.194113706289336], [151.56979536852037, -33.32687920807533], [151.5945714864758, -33.45967270474209], [151.6194099244393, -33.592495041319914], [15

# %% [markdown]
# ### load in layers to make connectivity mask
# - DEA mangroves
# - JCU saltmarsh and saltflats
# - CEM tidal Flats, Intertidal reefs and Intertidal rocky substratum (2), Mangroves (3), Saltmarsh (4), Intertidal Seagrass (5)

# %%
# Buffer input geobox and reduce resolution to ensure that the
# connectivity analysis is less affected by edge effects
buffer = 20000 # this is from load_connectivity_mask function. hardcoded here and will need to change if function value is change in load_connectivity_mask_aquatic
geobox_buffered = GeoBox.from_bbox(
    geobox.buffered(xbuff=buffer, ybuff=buffer).boundingbox,
    resolution=30,
    tight=True,
)

# %%
# Load srtm to buffered geobox
srtm_ds = dc.load(product = 'ga_srtm_dem1sv1_0', resampling="bilinear", like=geobox_buffered).squeeze()
srtm = srtm_ds.dem_h

# load in DEA mangroves
DEAmangrove = dc.load(product = 'ga_ls_mangrove_cover_cyear_3', time = ("2020", "2020"), like=geobox_buffered)
# if no mangroves within AOI, create dummy xr.dataarray
if DEAmangrove.data_vars == {}:
    mangrove = xr.DataArray(np.zeros_like(srtm), coords=srtm.coords, dims=srtm.dims, attrs=srtm.attrs)
else:
    # get output of mangrove == 1, not mangrove == 0
    mangrove = (DEAmangrove.canopy_cover_class != 255).squeeze('time')

# Load in JCU saltmarsh
geotiff_path = '/home/jovyan/gdata1/data/saltmarsh/JCU_Australia-saltmarsh-extent_v1-0.tif'
# load in geotiff again but with identical extent from srtm
saltmarsh = load_reproject(path=geotiff_path, how=geobox_buffered)

# Load in JCU saltflat
geotiff_path = '/home/jovyan/gdata1/data/saltmarsh/JCU_Australia-saltflat-extent_v1-0.tif'
# load in geotiff again but with identical extent from srtm
saltflat = load_reproject(path=geotiff_path, how=geobox_buffered)

# Load in CEM data (all except saltmarsh)
# CEM Saltmarsh layer will be load in separately
geotiff_path = '/home/jovyan/gdata1/projects/coastal/supratidal_forests/data/CEM_v002/ga_s2ls_coastalecosystems_cyear_3_2021--P1Y_interim_classification_0-0-2.tif'
CEM_data = load_reproject(path=geotiff_path, how=geobox_buffered)

CEM_layers = CEM_data.where((CEM_data == 2) | (CEM_data == 3) |(CEM_data == 5)) # all layers except saltmarsh
CEM = ~CEM_layers.isnull()

CEM_saltmarsh = CEM_data.where(CEM_data == 4) # saltmarsh in CEM equivalent to 4

# Saltmarsh intersection #
# Intersect both CEM and JCU saltmarsh layers based on common coordinates (inner join)
da_intersected = xr.align(CEM_saltmarsh, saltmarsh, join='inner')

# Extract the aligned DataArrays (now they share the same coordinates)
CEM_saltmarsh_aligned, saltmarsh_aligned = da_intersected

# Create a new DataArray based on the intersection (values aligned)
saltmarsh_intersection = CEM_saltmarsh_aligned + saltmarsh_aligned

saltmarsh_inter = ~saltmarsh_intersection.isnull()

# %%
# ocean nodata points
srtm_da = srtm == srtm.nodata

# combine masks for LCP, where 1 indicates aquatic features to start calculating LCP from, 0 are areas that will be given a LCP value
aquatic = xr.where((mangrove == True) | (saltmarsh_inter == True) | 
                   (saltflat == True) | (CEM == True) | (srtm_da == True), 1, 0).astype('bool')
aquatic = aquatic.compute()
# Out:
# /env/lib/python3.10/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(

# %% [markdown]
# ### run least cost path

# %%
# Run connectivity mask analysis
costdist_mask, costdist_da = load_connectivity_mask_aquatic(dc, geobox, starts_da = aquatic)

# %% [markdown]
# ### generate connectivity probability product

# %%
# mask on srtm valid values (i.e. mask out ocean from costdist_da)
# Access nodata value from the DataArray attributes
nodata_value = srtm.attrs.get("nodata", None)

# Replace nodata values with np.nan if nodata_value is defined
if nodata_value is not None:
    srtm_masked = srtm.where(srtm != nodata_value, np.nan)
else:
    print("No nodata value found in attributes.")
# Apply the mask and ensure NaNs are propagated form srtm_masked
costdist_da_masked = costdist_da.where(~np.isnan(srtm_masked))

# %%
min_value = 0
max_value = 3118 #  New upper limit based on LCP for the upper Mary River field data 

# Clip values above max_value
costdist_da_clip = xr.where(costdist_da_masked > max_value, np.nan, costdist_da_masked.values)

# %%
# Define the exponential function y = e^(-0.004 * x)
def apply_exponential(arr):
    return np.exp(-0.004 * arr)

# Apply the exponential function to the pixel values of the costdist_da_clip
# no need to invert now from last code iteration
costdist_da_norm = apply_exponential(costdist_da_clip)

# %%
costdist_da_norm.plot()
costdist_da_norm.odc.write_cog('SCL_connectivity_model_' + 'x' + str(bbox[0]) + 'y' + str(bbox[1]) + '.tif', overwrite=True)
# Out:
# PosixPath('SCL_connectivity_model_x64y32.tif')
